# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from classy import Class

# %%
from scipy.interpolate import interp1d

# %%
cosmo=Class()
cosmo.set({'gauge':'newtonian','output':'tCl mPk dTk vTk','omega_cdm':0.12038,'z_reio':11.357,'reionization_z_start_max':750,'A_bidm':1.9e-39,'a_bidm':0,'recombination':'hyrec','m_bidm':100,'bidm_type':'newpowerlaw','f_bidm':0.99,'n_bidm':-4,'z_reiomod_start':100})
# Out:
# True

# %%
cosmo.compute()

# %%
thermo = cosmo.get_thermodynamics()

# %%
bg = cosmo.get_background()

# %%
bgz = bg['z']
rhob = bg['(.)rho_b']

# %%
plt.plot(bgz,rhob)

# %%
plt.plot(bgz,rhob/(1+bgz))

# %%
sigma = thermo['sigma_b_dm']
R = thermo['Rbidm']
thz = thermo['z']

# %%
plt.loglog(thz,R)

# %%
plt.loglog(thz,sigma)

# %%
thz
# Out:
# array([0.00000000e+00, 9.07492093e-03, 2.24517173e-02, ...,
#        9.99850000e+03, 9.99900000e+03, 9.99950000e+03])

# %%
np.flip(bgz,0)
# Out:
# array([0.00000000e+00, 6.68404613e-03, 1.37685206e-02, ...,
#        9.86145640e+13, 9.93048659e+13, 1.00000000e+14])

# %%
np.shape(thz)
# Out:
# (20475,)

# %%
frho = interp1d(bgz,rhob)

# %%
plt.plot(thz,frho(thz))

# %%
plt.loglog(thz,sigma)

# %%
plt.loglog(thz,sigma*frho(thz)/(thz+1))
